# %%
import zipfile
with zipfile.ZipFile("all.zip","r") as zip_ref:
    zip_ref.extractall("")

# %%
import zipfile
with zipfile.ZipFile("test.zip","r") as zip_ref:
    zip_ref.extractall("")

# %%
import os

import glob
import matplotlib.pyplot as plt
from PIL import Image
import seaborn as sns
import ipywidgets as ipy
import pandas as pd
import numpy as np

# %%
train = pd.read_csv('train.csv')

# %%
train.head()
# Out:
#            id                                           rle_mask
# 0  575d24d81d                                                NaN
# 1  a266a2a9df                                          5051 5151
# 2  75efad62c1  9 93 109 94 210 94 310 95 411 95 511 96 612 96...
# 3  34e51dba6a  48 54 149 54 251 53 353 52 455 51 557 50 659 4...
# 4  4875705fb0  1111 1 1212 1 1313 1 1414 1 1514 2 1615 2 1716...

# %%
depths = pd.read_csv('depths.csv')

# %%
depths.head()
# Out:
#            id    z
# 0  4ac19fb269  306
# 1  1825fadf99  157
# 2  f59821d067  305
# 3  5b435fad9d  503
# 4  e340e7bfca  783

# %%
sns.distplot(depths['z'])
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
train_img_filepaths = sorted(glob.glob('{}/train_images/*'))
train_mask_filepaths = sorted(glob.glob('{}/train_masks/*'))

# %%
sample_submission = pd.read_csv("sample_submission.csv")
sample_submission[:3]
# Out:
#            id rle_mask
# 0  155410d6fa      1 1
# 1  78b32781d1      1 1
# 2  63db2a476a      1 1

# %%
submission = pd.read_csv('sample_submission.csv')

# %%
submission
# Out:
#                id rle_mask
# 0      155410d6fa      1 1
# 1      78b32781d1      1 1
# 2      63db2a476a      1 1
# 3      17bfcdb967      1 1
# 4      7ea0fd3c88      1 1
# 5      8a14fa3b33      1 1
# 6      1b4836f485      1 1
# 7      04013dfaae      1 1
# 8      5a005e1b95      1 1
# 9      fe53259bf6      1 1
# 10     03dee840bf      1 1
# 11     5be0000be2      1 1
# 12     6e166d6284      1 1
# 13     b07015747f      1 1
# 14     aac410c5d3      1 1
# 15     2230bca035      1 1
# 16     575d4ae82a      1 1
# 17     e9531eada5      1 1
# 18     894f6a1da6      1 1
# 19     fda5468e31      1 1
# 20     4ce3eb12cd      1 1
# 21     9853f60114      1 1
# 22     f40bfdeb45      1 1
# 23     7c5c9f8ba4      1 1
# 24     beeceae804      1 1
# 25     edc0dc3a4f      1 1
# 26     c4f145aef7      1 1
# 27     1fca9e9479      1 1
# 28     196638fe77      1 1
# 29     06f549734d      1 1
# ...           ...      ...
# 17970  5601dc4c6b      1 1
# 17971  3efd2d1d03      1 1
# 17972  9cba387403      1 1
# 17973  4bcefa3819      1 1
# 17974  23dc46cef1      1 1
# 17975  a3cfc9ec3a      1 1
# 17976  e0f166a352      1 1
# 17977  861e452121      1 1
# 17978  8d9e8acc95      1 1
# 17979  4359dac218      1 1
# 17980  15a52de24a      1 1
# 17981  4be61a973e      1 1
# 17982  eb61ff3bd3      1 1
# 17983  f18eb3b587      1 1
# 17984  5fea3149b3      1 1
# 17985  648b09f832      1 1
# 17986  ce7515118f      1 1
# 17987  c268afb4a1      1 1
# 17988  980b56419d      1 1
# 17989  bac4bf9fdd      1 1
# 17990  f734abe528      1 1
# 17991  76695059e8      1 1
# 17992  b5821bfa07      1 1
# 17993  7959b9bd53      1 1
# 17994  355a7edcb8      1 1
# 17995  c78063e0a6      1 1
# 17996  bfcdcd2720      1 1
# 17997  07c3553ef7      1 1
# 17998  9c2e45bf79      1 1
# 17999  41d0f0703c      1 1
#
# [18000 rows x 2 columns]
